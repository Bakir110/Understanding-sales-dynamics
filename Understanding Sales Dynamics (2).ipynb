# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
df = pd.read_csv('supermarket_sales.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A        NaN        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A        NaN        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#            Date   Time      Payment    cogs  gross margin percentage  \
# 0    01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1    03-08-2019  10:29         Cash   76.40                 4.761905
# 2    03-03-2019  13:23  Credit card  324.31                 4.761905
# 3     1/27/2019    NaN      Ewallet  465.76                 4.761905
# 4    02-08-2019  10:37      Ewallet  604.17                 4.761905
# ..          ...    ...          ...     ...                      ...
# 995   1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996  03-02-2019  17:16      Ewallet  973.80                 4.761905
# 997  02-09-2019  13:22         Cash   31.84                 4.761905
# 998   2/22/2019  15:33         Cash   65.82                 4.761905
# 999   2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %% [markdown]
# # Performing EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     973 non-null    object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     887 non-null    object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   995 non-null    float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A        NaN        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A        NaN        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# 2  03-03-2019  13:23  Credit card  324.31                 4.761905
# 3   1/27/2019    NaN      Ewallet  465.76                 4.761905
# 4  02-08-2019  10:37      Ewallet  604.17                 4.761905
#
#    gross income  Rating
# 0       26.1415     9.1
# 1        3.8200     9.6
# 2       16.2155     7.4
# 3       23.2880     8.4
# 4       30.2085     5.3

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total        Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675   1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900  03-02-2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320  02-09-2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110   2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990   2/18/2019  13:28     Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 995   40.35                 4.761905        2.0175     6.2
# 996  973.80                 4.761905       48.6900     4.4
# 997   31.84                 4.761905        1.5920     7.7
# 998   65.82                 4.761905        3.2910     4.1
# 999  618.38                 4.761905       30.9190     6.6

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  995.000000
# mean              4.761905e+00     15.379369    6.974372
# std               6.131498e-14     11.708825    1.720616
# min               4.761905e+00      0.508500    4.000000
# 25%               4.761905e+00      5.924875    5.500000
# 50%               4.761905e+00     12.088000    7.000000
# 75%               4.761905e+00     22.445250    8.500000
# max               4.761905e+00     49.650000   10.000000

# %%
df.isnull().sum()
# Out:
# Invoice ID                   0
# Branch                       0
# City                        27
# Customer type                0
# Gender                       0
# Product line                 0
# Unit price                   0
# Quantity                     0
# Tax 5%                       0
# Total                        0
# Date                         0
# Time                       113
# Payment                      0
# cogs                         0
# gross margin percentage      0
# gross income                 0
# Rating                       5
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.drop(['Invoice ID','Branch','Time'],axis=1,inplace=True)

# %%
df
# Out:
#           City Customer type  Gender            Product line  Unit price  \
# 0          NaN        Member  Female       Health and beauty       74.69
# 1    Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2       Yangon        Normal    Male      Home and lifestyle       46.33
# 3       Yangon        Member    Male       Health and beauty       58.22
# 4          NaN        Normal    Male       Sports and travel       86.31
# ..         ...           ...     ...                     ...         ...
# 995  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997     Yangon        Member    Male      Food and beverages       31.84
# 998     Yangon        Normal    Male      Home and lifestyle       65.82
# 999     Yangon        Member  Female     Fashion accessories       88.34
#
#      Quantity   Tax 5%      Total        Date      Payment    cogs  \
# 0           7  26.1415   548.9715  01-05-2019      Ewallet  522.83
# 1           5   3.8200    80.2200  03-08-2019         Cash   76.40
# 2           7  16.2155   340.5255  03-03-2019  Credit card  324.31
# 3           8  23.2880   489.0480   1/27/2019      Ewallet  465.76
# 4           7  30.2085   634.3785  02-08-2019      Ewallet  604.17
# ..        ...      ...        ...         ...          ...     ...
# 995         1   2.0175    42.3675   1/29/2019      Ewallet   40.35
# 996        10  48.6900  1022.4900  03-02-2019      Ewallet  973.80
# 997         1   1.5920    33.4320  02-09-2019         Cash   31.84
# 998         1   3.2910    69.1110   2/22/2019         Cash   65.82
# 999         7  30.9190   649.2990   2/18/2019         Cash  618.38
#
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ..                       ...           ...     ...
# 995                 4.761905        2.0175     6.2
# 996                 4.761905       48.6900     4.4
# 997                 4.761905        1.5920     7.7
# 998                 4.761905        3.2910     4.1
# 999                 4.761905       30.9190     6.6
#
# [1000 rows x 14 columns]

# %%
df['gross margin percentage'].unique()
# Out:
# array([4.76190476])

# %%
df.drop(['gross margin percentage'],axis=1,inplace=True)

# %%
df
# Out:
#           City Customer type  Gender            Product line  Unit price  \
# 0          NaN        Member  Female       Health and beauty       74.69
# 1    Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2       Yangon        Normal    Male      Home and lifestyle       46.33
# 3       Yangon        Member    Male       Health and beauty       58.22
# 4          NaN        Normal    Male       Sports and travel       86.31
# ..         ...           ...     ...                     ...         ...
# 995  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997     Yangon        Member    Male      Food and beverages       31.84
# 998     Yangon        Normal    Male      Home and lifestyle       65.82
# 999     Yangon        Member  Female     Fashion accessories       88.34
#
#      Quantity   Tax 5%      Total        Date      Payment    cogs  \
# 0           7  26.1415   548.9715  01-05-2019      Ewallet  522.83
# 1           5   3.8200    80.2200  03-08-2019         Cash   76.40
# 2           7  16.2155   340.5255  03-03-2019  Credit card  324.31
# 3           8  23.2880   489.0480   1/27/2019      Ewallet  465.76
# 4           7  30.2085   634.3785  02-08-2019      Ewallet  604.17
# ..        ...      ...        ...         ...          ...     ...
# 995         1   2.0175    42.3675   1/29/2019      Ewallet   40.35
# 996        10  48.6900  1022.4900  03-02-2019      Ewallet  973.80
# 997         1   1.5920    33.4320  02-09-2019         Cash   31.84
# 998         1   3.2910    69.1110   2/22/2019         Cash   65.82
# 999         7  30.9190   649.2990   2/18/2019         Cash  618.38
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 13 columns]

# %%
df['City'].unique()
# Out:
# array([nan, 'Naypyitaw', 'Yangon', 'Mandalay'], dtype=object)

# %%
city_counts = df['City'].value_counts()

# %%
city_counts
# Out:
# City
# Yangon       328
# Mandalay     327
# Naypyitaw    318
# Name: count, dtype: int64

# %%
most_frequent_city = city_counts.idxmax()

# %%
most_frequent_city
# Out:
# 'Yangon'

# %%
df['City'].fillna(most_frequent_city,inplace=True)

# %%
df['City'].isnull().sum()
# Out:
# 0

# %%
df[df['Rating'].isnull()]
# Out:
#          City Customer type  Gender            Product line  Unit price  \
# 11   Mandalay        Member    Male  Electronic accessories       25.51
# 12     Yangon        Normal  Female  Electronic accessories       46.95
# 15   Mandalay        Member  Female       Sports and travel       93.72
# 55  Naypyitaw        Normal  Female  Electronic accessories       85.98
# 57     Yangon        Normal    Male       Health and beauty       89.60
#
#     Quantity   Tax 5%     Total        Date  Payment    cogs  gross income  \
# 11         4   5.1020  107.1420  03-09-2019     Cash  102.04        5.1020
# 12         5  11.7375  246.4875  02-12-2019  Ewallet  234.75       11.7375
# 15         6  28.1160  590.4360   1/15/2019     Cash  562.32       28.1160
# 55         8  34.3920  722.2320   2/28/2019     Cash  687.84       34.3920
# 57         8  35.8400  752.6400  02-07-2019  Ewallet  716.80       35.8400
#
#     Rating
# 11     NaN
# 12     NaN
# 15     NaN
# 55     NaN
# 57     NaN

# %%
# Calculate the average rating for each product line
average_ratings = df.groupby('Product line')['Rating'].mean()

# Fill the null values in the Rating column based on the average ratings
df['Rating'] = df.apply(lambda row: average_ratings[row['Product line']] if pd.isnull(row['Rating']) else row['Rating'], axis=1)

# %%
df['Rating'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# City             0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       0
# Quantity         0
# Tax 5%           0
# Total            0
# Date             0
# Payment          0
# cogs             0
# gross income     0
# Rating           0
# dtype: int64

# %%
df
# Out:
#           City Customer type  Gender            Product line  Unit price  \
# 0       Yangon        Member  Female       Health and beauty       74.69
# 1    Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2       Yangon        Normal    Male      Home and lifestyle       46.33
# 3       Yangon        Member    Male       Health and beauty       58.22
# 4       Yangon        Normal    Male       Sports and travel       86.31
# ..         ...           ...     ...                     ...         ...
# 995  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997     Yangon        Member    Male      Food and beverages       31.84
# 998     Yangon        Normal    Male      Home and lifestyle       65.82
# 999     Yangon        Member  Female     Fashion accessories       88.34
#
#      Quantity   Tax 5%      Total        Date      Payment    cogs  \
# 0           7  26.1415   548.9715  01-05-2019      Ewallet  522.83
# 1           5   3.8200    80.2200  03-08-2019         Cash   76.40
# 2           7  16.2155   340.5255  03-03-2019  Credit card  324.31
# 3           8  23.2880   489.0480   1/27/2019      Ewallet  465.76
# 4           7  30.2085   634.3785  02-08-2019      Ewallet  604.17
# ..        ...      ...        ...         ...          ...     ...
# 995         1   2.0175    42.3675   1/29/2019      Ewallet   40.35
# 996        10  48.6900  1022.4900  03-02-2019      Ewallet  973.80
# 997         1   1.5920    33.4320  02-09-2019         Cash   31.84
# 998         1   3.2910    69.1110   2/22/2019         Cash   65.82
# 999         7  30.9190   649.2990   2/18/2019         Cash  618.38
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 13 columns]

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='Product line', data=df, order=df['Product line'].value_counts().index)
plt.title('Distribution of Product Line')
plt.xlabel('Count')
plt.ylabel('Product Line')
plt.show()

# %%
plt.figure(figsize=(10, 6))
total_sales = df.groupby('Product line')['Total'].sum().sort_values(ascending=False)
sns.barplot(y=total_sales.index, x=total_sales.values)
plt.title('Total Sales by Product Line')
plt.xlabel('Total Sales')
plt.ylabel('Product Line')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Rating'], kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Unit price', y='Quantity', data=df)
plt.title('Relationship between Unit Price and Quantity')
plt.xlabel('Unit Price')
plt.ylabel('Quantity')
plt.show()

# %%
# What is the Average Rating for each product line

avg_rating = df.groupby("Product line")[['Rating']].mean().sort_values(by='Rating',ascending=False)
avg_rating
# Out:
#                           Rating
# Product line
# Food and beverages      7.113218
# Fashion accessories     7.029213
# Health and beauty       7.005960
# Sports and travel       6.930909
# Electronic accessories  6.916766
# Home and lifestyle      6.837500

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Product line',y='Rating',data = avg_rating)
plt.xticks(rotation = "vertical")
plt.show()

# %%
# How much total business done by male and female?

total_business = df.groupby('Gender')[['Total']].sum()
total_business
# Out:
#              Total
# Gender
# Female  167882.925
# Male    155083.824

# %%
plt.figure(figsize=(10,5))
plt.pie(total_business['Total'], labels=total_business.index, autopct='%1.1f%%')
plt.title('Total Business by Gender')
plt.show()

# %%
# Which product line has the highest average unit price?

avg_unit_price = df.groupby('Product line')['Unit price'].mean()
avg_unit_price
# Out:
# Product line
# Electronic accessories    53.551588
# Fashion accessories       57.153652
# Food and beverages        56.008851
# Health and beauty         54.854474
# Home and lifestyle        55.316937
# Sports and travel         56.993253
# Name: Unit price, dtype: float64

# %%
sns.barplot(x='Product line', y='Unit price', data=df)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.title('Average Unit Price by Product Line')
plt.xlabel('Product Line')
plt.ylabel('Average Unit Price')
plt.show()

# %%
# What is the total tax amount collected for each city?

tax = df.groupby('City')['Tax 5%'].sum()
tax
# Out:
# City
# Mandalay     4965.1665
# Naypyitaw    5140.6185
# Yangon       5273.5840
# Name: Tax 5%, dtype: float64

# %%
sns.catplot(data=df,x='City',y='Tax 5%')
# Out:
# C:\Users\Baqir\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# What is the overall gross income for each date?

gross_income_date = df.groupby('Date')['gross income'].sum()
gross_income_date
# Out:
# Date
# 01-01-2019    225.9610
# 01-02-2019     92.6430
# 01-03-2019     98.9585
# 01-04-2019     77.3185
# 01-05-2019    168.4135
#                 ...
# 3/26/2019      93.4530
# 3/27/2019     138.2295
# 3/28/2019     106.1620
# 3/29/2019     191.5830
# 3/30/2019     213.6695
# Name: gross income, Length: 89, dtype: float64

# %%
#What is the total revenue generated by each customer type?

total_revenue = df.groupby('Customer type')['Total'].sum()
total_revenue
# Out:
# Customer type
# Member    164223.444
# Normal    158743.305
# Name: Total, dtype: float64

# %%
sns.barplot(data = df,x='Customer type', y='Total')
# Out:
# <Axes: xlabel='Customer type', ylabel='Total'>

# %%
# How many units of each product line were sold in each city?

product_line_city = df.groupby(['Product line', 'City'])['Quantity'].sum()
product_line_city
# Out:
# Product line            City
# Electronic accessories  Mandalay     307
#                         Naypyitaw    323
#                         Yangon       341
# Fashion accessories     Mandalay     296
#                         Naypyitaw    318
#                         Yangon       288
# Food and beverages      Mandalay     270
#                         Naypyitaw    357
#                         Yangon       325
# Health and beauty       Mandalay     309
#                         Naypyitaw    277
#                         Yangon       268
# Home and lifestyle      Mandalay     292
#                         Naypyitaw    244
#                         Yangon       375
# Sports and travel       Mandalay     322
#                         Naypyitaw    265
#                         Yangon       333
# Name: Quantity, dtype: int64

# %%
# What is the average unit price for each gender?

gender = df.groupby('Gender')['Unit price'].sum()
gender
# Out:
# Gender
# Female    27687.24
# Male      27984.89
# Name: Unit price, dtype: float64

# %%
#Payment Method Distribution

plt.figure(figsize=(8, 5))
sns.countplot(x='Payment', data=df)
plt.title('Payment Method Distribution')
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.show()

# %%
#Gender Distribution

plt.figure(figsize=(8, 5))
sns.countplot(x='Gender', data=df)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
#Average Gross Income by City

avg_gross_income = df.groupby('City')['gross income'].mean().sort_values(ascending=False)
sns.barplot(x=avg_gross_income.index, y=avg_gross_income.values)
plt.title('Average Gross Income by City')
plt.xlabel('City')
plt.ylabel('Average Gross Income')
plt.show()

# %%
#Customer Type
sns.swarmplot(x="Customer type",  y = "Rating",  hue = "City", data =df).set_title("Customer Type")
# Out:
# Text(0.5, 1.0, 'Customer Type')

# %%
#Relationship between Quantity and Gross Income

sns.scatterplot(x='Quantity', y='gross income', data=df,marker="v")
plt.title('Relationship between Quantity and Gross Income')
plt.xlabel('Quantity')
plt.ylabel('Gross Income')
plt.show()

# %%
#Relationship between Unit Price and Total Sales

sns.scatterplot(x='Unit price', y='Total',data=df)
plt.title('Relationship between Unit Price and Total Sales')
plt.xlabel('Unit Price')
plt.ylabel('Total Sales')
plt.show()

# %%
df.hist(figsize=(20,14))
plt.show()

# %%
numeric_data = df.drop(['City', 'Customer type', 'Gender', 'Product line', 'Date', 'Payment'], axis=1)

# Calculate the correlation matrix
corr = numeric_data.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Linear Regression Algorithm

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Assuming 'Total' is the target variable want to predict
X = df.drop('Total', axis=1)  # Features
y = df['Total']  # Target variable

# %%
X
# Out:
#           City Customer type  Gender            Product line  Unit price  \
# 0       Yangon        Member  Female       Health and beauty       74.69
# 1    Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2       Yangon        Normal    Male      Home and lifestyle       46.33
# 3       Yangon        Member    Male       Health and beauty       58.22
# 4       Yangon        Normal    Male       Sports and travel       86.31
# ..         ...           ...     ...                     ...         ...
# 995  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997     Yangon        Member    Male      Food and beverages       31.84
# 998     Yangon        Normal    Male      Home and lifestyle       65.82
# 999     Yangon        Member  Female     Fashion accessories       88.34
#
#      Quantity   Tax 5%        Date      Payment    cogs  gross income  Rating
# 0           7  26.1415  01-05-2019      Ewallet  522.83       26.1415     9.1
# 1           5   3.8200  03-08-2019         Cash   76.40        3.8200     9.6
# 2           7  16.2155  03-03-2019  Credit card  324.31       16.2155     7.4
# 3           8  23.2880   1/27/2019      Ewallet  465.76       23.2880     8.4
# 4           7  30.2085  02-08-2019      Ewallet  604.17       30.2085     5.3
# ..        ...      ...         ...          ...     ...           ...     ...
# 995         1   2.0175   1/29/2019      Ewallet   40.35        2.0175     6.2
# 996        10  48.6900  03-02-2019      Ewallet  973.80       48.6900     4.4
# 997         1   1.5920  02-09-2019         Cash   31.84        1.5920     7.7
# 998         1   3.2910   2/22/2019         Cash   65.82        3.2910     4.1
# 999         7  30.9190   2/18/2019         Cash  618.38       30.9190     6.6
#
# [1000 rows x 12 columns]

# %%
y
# Out:
# 0       548.9715
# 1        80.2200
# 2       340.5255
# 3       489.0480
# 4       634.3785
#          ...
# 995      42.3675
# 996    1022.4900
# 997      33.4320
# 998      69.1110
# 999     649.2990
# Name: Total, Length: 1000, dtype: float64

# %%
# Convert categorical variables into dummy/indicator variables
X = pd.get_dummies(X)

# %%
X
# Out:
#      Unit price  Quantity   Tax 5%    cogs  gross income  Rating  \
# 0         74.69         7  26.1415  522.83       26.1415     9.1
# 1         15.28         5   3.8200   76.40        3.8200     9.6
# 2         46.33         7  16.2155  324.31       16.2155     7.4
# 3         58.22         8  23.2880  465.76       23.2880     8.4
# 4         86.31         7  30.2085  604.17       30.2085     5.3
# ..          ...       ...      ...     ...           ...     ...
# 995       40.35         1   2.0175   40.35        2.0175     6.2
# 996       97.38        10  48.6900  973.80       48.6900     4.4
# 997       31.84         1   1.5920   31.84        1.5920     7.7
# 998       65.82         1   3.2910   65.82        3.2910     4.1
# 999       88.34         7  30.9190  618.38       30.9190     6.6
#
#      City_Mandalay  City_Naypyitaw  City_Yangon  Customer type_Member  ...  \
# 0            False           False         True                  True  ...
# 1            False            True        False                 False  ...
# 2            False           False         True                 False  ...
# 3            False           False         True                  True  ...
# 4            False           False         True                 False  ...
# ..             ...             ...          ...                   ...  ...
# 995          False            True        False                 False  ...
# 996           True           False        False                 False  ...
# 997          False           False         True                  True  ...
# 998          False           False         True                 False  ...
# 999          False           False         True                  True  ...
#
#      Date_3/24/2019  Date_3/25/2019  Date_3/26/2019  Date_3/27/2019  \
# 0             False           False           False           False
# 1             False           False           False           False
# 2             False           False           False           False
# 3             False           False           False           False
# 4             False           False           False           False
# ..              ...             ...             ...             ...
# 995           False           False           False           False
# 996           False           False           False           False
# 997           False           False           False           False
# 998           False           False           False           False
# 999           False           False           False           False
#
#      Date_3/28/2019  Date_3/29/2019  Date_3/30/2019  Payment_Cash  \
# 0             False           False           False         False
# 1             False           False           False          True
# 2             False           False           False         False
# 3             False           False           False         False
# 4             False           False           False         False
# ..              ...             ...             ...           ...
# 995           False           False           False         False
# 996           False           False           False         False
# 997           False           False           False          True
# 998           False           False           False          True
# 999           False           False           False          True
#
#      Payment_Credit card  Payment_Ewallet
# 0                  False             True
# 1                  False            False
# 2                   True            False
# 3                  False             True
# 4                  False             True
# ..                   ...              ...
# 995                False             True
# 996                False             True
# 997                False            False
# 998                False            False
# 999                False            False
#
# [1000 rows x 111 columns]

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create linear regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict on test dataset
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([ 523.971 ,  616.98  ,  408.7335,  135.3555,   45.927 ,  618.975 ,
#         127.827 ,  731.6925,  450.1035,  138.1275,  422.73  ,  463.428 ,
#         212.7825,  252.252 ,  290.0835,  331.128 ,  587.664 ,  216.846 ,
#         757.365 ,  185.094 ,  416.178 ,  166.236 ,  128.016 ,  125.706 ,
#         247.8735,  195.594 ,  742.2975,   30.996 ,  145.5825,   56.469 ,
#          75.5475,  609.    ,   96.1905,  432.768 ,  193.011 ,  174.3   ,
#         667.38  ,  198.639 ,  193.074 ,  192.843 ,  214.746 ,  922.635 ,
#          74.7075,  180.873 ,   93.0405,  400.764 ,  221.886 ,   68.2395,
#         343.224 ,  281.169 ,  430.71  ,  101.64  ,   69.09  ,  269.934 ,
#         181.44  ,  494.1825,  461.5275,   60.816 ,  456.288 ,  222.138 ,
#         121.128 ,   33.936 ,   84.756 ,  942.4485,  381.3915,  510.615 ,
#         370.125 ,  760.452 ,  939.54  ,  118.251 ,  391.419 ,  127.26  ,
#         293.139 ,   89.0715,   65.604 ,  697.368 ,  764.19  ,  253.008 ,
#          76.755 ,  745.836 ,  305.55  ,   70.287 ,  352.5795,  614.943 ,
#         218.0745,  270.585 ,   69.111 ,  829.08  ,  384.72  ,  395.892 ,
#         523.3725,  138.663 ,  235.872 ,  796.908 ,   57.6975,  348.306 ,
#         233.1   ,   44.5935,  166.005 ,  681.4395,  525.231 ,  379.9215,
#         579.8415,   69.6675,  697.935 ,   63.2625,  142.002 ,  932.337 ,
#         323.064 ,  397.614 ,  570.78  ,  216.4365,  334.4775,  333.984 ,
#         401.73  ,  147.798 ,   90.699 ,   26.7225,  148.68  ,  190.155 ,
#         485.5725,  383.7645,  130.8825,  709.317 ,  232.155 ,  228.123 ,
#          75.936 ,   20.1075,  131.922 ,  144.963 ,  147.672 ,  624.33  ,
#         723.24  ,   42.3675,  926.9505,  722.232 ,  836.304 ,   19.194 ,
#         441.756 ,  152.838 ,   32.277 ,   94.185 ,  856.4535,   38.85  ,
#         148.995 ,  313.74  ,   90.3   ,  788.508 ,   10.6785,   41.391 ,
#         609.168 ,  918.729 ,  167.58  ,  951.825 ,  943.299 ,  310.59  ,
#         172.011 ,  261.198 ,   77.931 ,  175.014 ,   46.683 ,   86.247 ,
#         259.77  ,  397.215 ,  106.5015,  300.573 ,  252.042 ,  211.365 ,
#         820.365 ,  503.559 ,  793.548 ,   40.53  ,   34.629 ,  633.108 ,
#         431.445 ,  461.286 ,  494.76  ,  276.948 ,  495.3165,  308.574 ,
#         209.769 ,  588.42  ,  701.8515,  164.682 ,  295.407 ,  216.846 ,
#         374.388 ,  343.056 ,  479.64  ,  597.0405,  188.0025,  779.31  ,
#         104.6745,  374.7975,  146.223 ,  237.426 ,  404.355 ,   95.6655,
#          84.9765,  822.255 ,  235.2105,  122.5245,  458.6925, 1034.46  ,
#         202.335 ,  164.43  ,  357.588 ,  217.2555,  637.728 ,  441.588 ,
#         166.635 ,  950.25  ,   57.876 ,  130.032 ,   49.4235,  103.635 ,
#         207.48  ,  536.991 ,  435.12  ,  131.208 ,  530.67  ,   56.406 ,
#         104.832 ,  867.615 ,  446.439 ,  340.5255,   74.76  , 1042.65  ,
#         122.472 ,   77.658 ,  140.6475,   63.9975,  344.4   ,  597.6285,
#         202.818 ,  737.7615,   33.3585,  304.983 ,  829.71  ,   49.308 ,
#         489.048 ,   93.2925,  429.1665,  455.1225,  295.6905,  860.685 ,
#         145.068 ,  189.0945,  256.7775,   78.603 ,  161.7   ,  804.3   ,
#         432.9885,  317.835 ,  258.678 ,  324.2925,  377.58  ,   44.9925,
#          26.733 ,  627.6165,  176.4   ,  572.775 ,   78.435 ,  148.974 ,
#        1002.12  ,   76.5765,   97.419 ,  345.786 ,  246.6765,   55.881 ,
#          72.87  ,  115.08  ,  423.738 ,  439.8975,  132.027 ,  172.746 ,
#          91.77  ,  343.413 ,  304.542 ,  369.684 ,  226.065 ,  257.145 ,
#          94.1745,  423.15  ,  881.307 ,   37.611 ,   78.7185,   41.076 ,
#         155.652 ,  125.7165,  176.925 ,   63.9135,   33.495 ,  269.535 ,
#         209.559 ,   22.659 ,  270.018 ,  353.1675,  772.38  ,  484.5225])

# %%
# Calculate mean squared error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 8.776328954258886e-26

# %%
# Plotting the predicted values against the actual values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs. Predicted')
plt.show()

# %%
#lets find the categorialfeatures
list_1=list(df.columns)

# %%
list_cate=[]
for i in list_1:
    if df[i].dtype=='object':
        list_cate.append(i)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in list_cate:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#      City  Customer type  Gender  Product line  Unit price  Quantity   Tax 5%  \
# 0       2              0       0             3       74.69         7  26.1415
# 1       1              1       0             0       15.28         5   3.8200
# 2       2              1       1             4       46.33         7  16.2155
# 3       2              0       1             3       58.22         8  23.2880
# 4       2              1       1             5       86.31         7  30.2085
# ..    ...            ...     ...           ...         ...       ...      ...
# 995     1              1       1             3       40.35         1   2.0175
# 996     0              1       0             4       97.38        10  48.6900
# 997     2              0       1             2       31.84         1   1.5920
# 998     2              1       1             4       65.82         1   3.2910
# 999     2              0       0             1       88.34         7  30.9190
#
#          Total  Date  Payment    cogs  gross income  Rating
# 0     548.9715     4        2  522.83       26.1415     9.1
# 1      80.2200    31        0   76.40        3.8200     9.6
# 2     340.5255    26        1  324.31       16.2155     7.4
# 3     489.0480    50        2  465.76       23.2880     8.4
# 4     634.3785    19        2  604.17       30.2085     5.3
# ..         ...   ...      ...     ...           ...     ...
# 995    42.3675    52        2   40.35        2.0175     6.2
# 996  1022.4900    25        2  973.80       48.6900     4.4
# 997    33.4320    20        0   31.84        1.5920     7.7
# 998    69.1110    64        0   65.82        3.2910     4.1
# 999   649.2990    60        0  618.38       30.9190     6.6
#
# [1000 rows x 13 columns]

# %% [markdown]
# # DecisionTree

# %%
y=df['Gender']
x=df.drop('Gender',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 800
# 200
# 800
# 200

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=6, random_state=123,criterion='entropy')

dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=123)

# %%
y_pred=dtree.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",dtree.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.53      0.52      0.53       100
#            1       0.53      0.54      0.53       100
#
#     accuracy                           0.53       200
#    macro avg       0.53      0.53      0.53       200
# weighted avg       0.53      0.53      0.53       200
#
# Confusion Matrix:
#  [[52 48]
#  [46 54]]
# Training Score:
#  67.0
